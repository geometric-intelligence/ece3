# %% [markdown]
# # Market Inventory Lab Session
#
# Welcome to your first lab! Today you'll practice using variables, data types, and basic operations by building a market inventory system.
#
# **Remember:** You've learned about:
# - Variables and assignment (`=`)
# - Data types: integers, floats, strings, lists, tuples, dictionaries
# - Indexing and slicing
# - Basic operators (`+`, `-`, `*`, `/`)
# - Membership operators (`in`, `not in`)
#
# Let's get started!

# %% [markdown]
# ## Part 1: Creating the Inventory (Dictionary Basics)

# %% [markdown]
# ### Exercise 1.1
# Create an empty dictionary called `market_inventory` and print it.

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.2
# Create a market inventory dictionary with these items:
# - "apples": 50
# - "bananas": 30
# - "oranges": 25
#
# Print the entire inventory.

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.3
# Add a new item to the inventory:
# - "grapes": 40
#
# Print the updated inventory.

# %%
# Your code here

# %% [markdown]
# ## Part 2: Checking Inventory

# %% [markdown]
# ### Exercise 2.1
# Print how many apples are in the inventory.
#
# **Hint:** Access the value using the key: `market_inventory["apples"]`

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.2
# Check if "mangoes" is in the inventory using the `in` operator.
# Print the result (it will be True or False).

# %%
# Your code here

# %% [markdown]
# ### Exercise 2.3
# Check if "bananas" is in the inventory. Print the result.

# %%
# Your code here

# %% [markdown]
# ## Part 3: Updating Inventory

# %% [markdown]
# ### Exercise 3.1
# The market received a new shipment! Add 20 more apples to the existing amount.
#
# **Hint:** `market_inventory["apples"] = market_inventory["apples"] + 20`
#
# Print the new apple count.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3.2
# 15 bananas were sold. Reduce the banana count by 15.
#
# Print the new banana count.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3.3
# Print the entire updated inventory to verify your changes.

# %%
# Your code here

# %% [markdown]
# ## Part 4: Creating a Shopping List

# %% [markdown]
# ### Exercise 4.1
# Create a list called `shopping_list` with these items:
# ```python
# ["apples", "milk", "bananas"]
# ```
# Print the shopping list.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4.2
# Add "bread" to the shopping list using `.append()`
#
# Print the updated shopping list.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4.3
# Check if the first item in your shopping list is available in the market inventory.
#
# **Hint:** First get the first item using `shopping_list[0]`, then check if it's in the inventory using `in`.
#
# Print the result.

# %%
# Your code here

# %% [markdown]
# ## Part 5: Multiple Operations

# %% [markdown]
# ### Exercise 5.1
# Create a second dictionary called `prices` with:
# - "apples": 2.5
# - "bananas": 1.8
# - "oranges": 3.0
# - "grapes": 4.5
#
# Print the prices dictionary.

# %%
# Your code here

# %% [markdown]
# ### Exercise 5.2
# Calculate the total value of all apples in inventory:
# - Multiply the number of apples by the price per apple
# - Store this in a variable called `apple_value`
# - Print the result

# %%
# Your code here

# %% [markdown]
# ### Exercise 5.3
# Calculate the total value of bananas and oranges combined.
#
# **Hint:** (banana_quantity × banana_price) + (orange_quantity × orange_price)
#
# Print the result.

# %%
# Your code here

# %% [markdown]
# ## Part 6: Removing Items

# %% [markdown]
# ### Exercise 6.1
# The market stopped selling grapes. Remove "grapes" from the inventory using `.pop("grapes")`
#
# **Note:** This will return the value that was removed.

# %%
# Your code here

# %% [markdown]
# ### Exercise 6.2
# Print the inventory to confirm grapes are removed.

# %%
# Your code here

# %% [markdown]
# ## Bonus Challenge

# %% [markdown]
# Create a dictionary called `customer_order` with:
# - "apples": 10
# - "bananas": 5
#
# Calculate and print:
# 1. The remaining apples in inventory after this order
# 2. The remaining bananas in inventory after this order
# 3. The total cost of this customer's order
#
# Print all three results with descriptive labels.

# %%
# Your code here

# %% [markdown]
# ## Congratulations!
#
# You've completed the Market Inventory Lab! You practiced:
# - Creating and manipulating dictionaries
# - Working with lists
# - Using indexing to access values
# - Performing arithmetic operations
# - Using membership operators
#
# Great work!
