# %% [markdown]
# # Unit 03: Summarizing Data

# %% [markdown]
# # 🧾 Mid-Quarter Feedback Summary
#
# **ECE 3: Anonymous Student Survey**
#
# Thank you for all your feedback!!
#
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_mookie_thank_you.webp" alt="Mean, Median, Mode illustration" width="600px">
# </div>

# %% [markdown]
# ---
# ## Datacamp Feedback - What did you think of Datacamp?
#
# | Rating        | % of Responses | # of Responses |
# |----------------|----------------|----------------|
# | Excellent      | 8%             | 8              |
# | Good           | 43%            | 43             |
# | Neutral        | 31%            | 31             |
# | Bad            | 16%            | 16             |
# | The Worst      | 2%             | 2              |
#
# Some people like it, some don't!
# It’s normal that datacamp, or the labs, goes beyond what’s seen in class: it’s why they are graded on completion, and not on score.

# %% [markdown]
# ## 📊 Lecture Feedback
#
# <div style="
#   display: flex;
#   justify-content: center;
#   align-items: flex-start;
#   gap: 50px;
#   margin-top: 30px;
# ">
#
#   <!-- Left: Article preview -->
#   <div style="text-align:center; max-width:700px;">
#     <img src="figs/03_adele_difficulty.png" alt="Nature Aging article" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Unit 1 difficulty of theoretical content.</i>
#     </p>
#   </div>
#
#   <!-- Right: Figure overview -->
#   <div style="text-align:center; max-width:700px;">
#     <img src="figs/03_fran_difficulty.png" alt="Study overview" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Unit 2 difficulty of theoretical content.</i>
#     </p>
#   </div>
# </div>
# <small>Unit 2 is expected to be more technical and mathy! Unit 3 and 4 should be less. </small>

# %% [markdown]
# ## 📊 Lecture Feedback
#
# <div style="
#   display: flex;
#   justify-content: center;
#   align-items: flex-start;
#   gap: 50px;
#   margin-top: 30px;
# ">
#
#   <!-- Left: Article preview -->
#   <div style="text-align:center; max-width:700px;">
#     <img src="figs/03_adele_pace.png" alt="Nature Aging article" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Unit 1 pace of theoretical content.</i>
#     </p>
#   </div>
#
#   <!-- Right: Figure overview -->
#   <div style="text-align:center; max-width:700px;">
#     <img src="figs/03_fran_pace.png" alt="Study overview" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Unit 2 pace of theoretical content.</i>
#     </p>
#   </div>
# </div>

# %% [markdown]
# ## 🎓 Quiz Ratings
#
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_quiz_difficulty.png" alt="Mean, Median, Mode illustration" width="600px">
# </div>
#
# 📝 *Notes:*
# <ul>
#   <li> Lowest quiz grade is dropped. </li>
#   <li>Quiz 1 was easier than Quiz 2 (one of the TAs who had an accident had the quizzes with him).</li>
# </ul>

# %% [markdown]
# ## How we are taking this feedback into account:
#
# - We will provide a practice quiz 3 with solutions.
# - Some want a final project, while we will not have a final project, if you want to explore projects you can particiipate in the Topological Deep Learning Challenge.
#
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_tdl_challenge.jpg" alt="Mean, Median, Mode illustration" width="600px">
# </div>

# %% [markdown]
# # Outline of ECE 3
#
# - 01: Welcome to Python
# - 02: Computing with Data in Python
# - **03: Summarizing Data in Python**
# - 04: Predicting from Data with Machine Learning in Python
#   - A. Clustering
#   - B. Linear regression

# %% [markdown]
# # Outline of Unit 03
#
# - **03: Computing with Data in Python**
#   - Why do we summarize data?
#   - Continous vs. Categorical
#       - Summarizing Continous Data
#           - Mean, Median, Mode, Standard Deviation, Variance
#       - <b> Summarizing Categorical Data</b>
#           - <b>Frequency, Percentage, Unique</b>
#   - <b>Visualizing Data</b>
#      - <b> Histograms, box plots (quartiles), bar plots, pie charts </b>
#   - Comparing 2 variables
#      - Correlation, Covariance, Scatter Plot, line plots
#   - Input/Output

# %% [markdown]
# ## Recap: What is continous vs. categorical?

# %% [markdown]
# <h1> Summarizing Categorical Variables </h1>
# <ul>
#   <li>Usually summarized with <b>frequencies</b>, <b>percents</b>, and <b>unique variables</b></li>
#   <li>Visualized with bar plots, pie charts and line plots</li>
#   <li> <b>Reminder</b>: We use mode as well, but we have already seen that! </li>
# </ul>

# %% [markdown]
# # Frequency
#
# $\color{#EF5645}{\text{Definition}}$: The **frequency** of a category is the number of times it appears in a dataset.
#
# $\color{#003660}{\text{In Python}}$, we use the function `value_counts()` from `pandas`.
#
# **Insight** You can get mode easily once you know frequency!

# %% [markdown]
# # Real-World Example: Frequency in Research
#
# In real data analysis, **frequency** helps describe how often each category or group appears in a study.
# Researchers count participants with each genetic mutation to understand sample composition.
#
# <div style="
#   display: flex;
#   justify-content: center;
#   align-items: flex-start;
#   gap: 50px;
#   margin-top: 30px;
# ">
#
#   <!-- Left: Article preview -->
#   <div style="text-align:center; max-width:500px;">
#     <img src="figs/03_frequency_article.png" alt="Nature Aging article" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Study published in <b>Nature Aging</b> (2025).</i>
#     </p>
#   </div>
#
#   <!-- Right: Figure overview -->
#   <div style="text-align:center; max-width:500px;">
#     <img src="figs/03_frequency_fig.png" alt="Study overview" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Each genetic group (C9orf72, GRN, MAPT, controls) has its own frequency count (<b>n</b>).</i>
#     </p>
#   </div>
# </div>

# %% [markdown]
# $\color{#047C91}{\text{Exercise}}$ How would we find the frequencies without a built in function?

# %%
def count_frequencies(items):
    freq = {}
    for x in items:
        print(freq)
        print(x)
        if x in freq:
            freq[x] += 1
        else:
            freq[x] = 1
    return freq

data = ['Red', 'Blue', 'Red', 'Green', 'Blue', 'Red']
print(count_frequencies(data))
# Out:
# {}
# Red
# {'Red': 1}
# Blue
# {'Red': 1, 'Blue': 1}
# Red
# {'Red': 2, 'Blue': 1}
# Green
# {'Red': 2, 'Blue': 1, 'Green': 1}
# Blue
# {'Red': 2, 'Blue': 2, 'Green': 1}
# Red
# {'Red': 3, 'Blue': 2, 'Green': 1}

# %% [markdown]
# ## 📊 `Series.value_counts()` — Parameters Explained
#
# **Function:**
# `Series.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True)`
#
# ---
#
# ### 🔹 **Parameters**
#
# | Parameter | Type | Default | Meaning |
# |------------|------|----------|----------|
# | **normalize** | `bool` | `False` | If `True`, returns **relative frequencies** (proportions) instead of raw counts. <br>• `False` → counts (e.g., 50) <br>• `True` → fractions (e.g., 0.50) |
# | **sort** | `bool` | `True` | Sorts the output by **frequency** (most common first). <br>Set to `False` to preserve the original order of appearance. |
# | **ascending** | `bool` | `False` | If `True`, sorts in **ascending order** (least frequent first). <br>Used only when `sort=True`. |
# | **bins** | `int` | `None` | For **numeric data only** — splits values into equal-width **bins** (intervals), like `pd.cut`. <br>Example: `bins=4` groups ages into 4 ranges. |
# | **dropna** | `bool` | `True` | Whether to **ignore missing values** (`NaN`). <br>Set to `False` to include them in the result. |
#
# ---

# %%
import pandas as pd

colors = pd.Series(['Red', 'Blue', 'Red', 'Green', 'Blue', 'Red', 'Blue', 'Blue'])
colors.value_counts()
# Out:
# Blue     4
# Red      3
# Green    1
# Name: count, dtype: int64

# %%
colors.value_counts(sort=False)
# Out:
# Red      3
# Blue     4
# Green    1
# Name: count, dtype: int64

# %%
colors.value_counts(ascending=True)
# Out:
# Green    1
# Red      3
# Blue     4
# Name: count, dtype: int64

# %% [markdown]
# # Relative Frequency (Percent)
#
# $\color{#EF5645}{\text{Definition}}$: The **relative frequency** or **percentage** shows how common each category is compared to the total.
#
# $$\text{Percent} = \frac{\text{Count of Category}}{\text{Total Count}} \times 100$$
#
# How would we do this in python using what we just saw?

# %% [markdown]
# # Real-World Example: Percentage in Research
#
#
# <div style="
#   display: flex;
#   justify-content: center;
#   align-items: flex-start;
#   gap: 50px;
#   margin-top: 30px;
# ">
#
#   <!-- Left: Article preview -->
#   <div style="text-align:center; max-width:500px;">
#     <img src="figs/03_percentage_article.png" alt="Nature Aging article" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Study published in <b>Nature Water</b> (2025).</i>
#     </p>
#   </div>
#
#   <!-- Right: Figure overview -->
#   <div style="text-align:center; max-width:500px;">
#     <img src="figs/03_percentage_fig.png" alt="Study overview" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#       <i>Each genetic group (C9orf72, GRN, MAPT, controls) has its own frequency count (<b>n</b>).</i>
#     </p>
#   </div>
# </div>

# %%
colors.value_counts(normalize=True)
# Out:
# Blue     0.500
# Red      0.375
# Green    0.125
# Name: proportion, dtype: float64

# %%
colors.value_counts(normalize=True) * 100
# Out:
# Blue     50.0
# Red      37.5
# Green    12.5
# Name: proportion, dtype: float64

# %% [markdown]
# $\color{#047C91}{\text{Exercise}}$: When would frequency be a useful metric over relative frequency and vice versa?
#
# Hint: You've already seen both this class.

# %% [markdown]
# At a local animal shelter, there are 100 dogs and 2 cats.
# One day, one dog is adopted together with one of the cats.
#
# A volunteer posts on the notice board:
#
# “1% of the dogs got adopted with 50% of the cats!”

# %% [markdown]
# Use frequency when the absolute number matters — when you care about how many observations there are, not just how they compare proportionally.
#
# Ex:
# **Scenario:**
# A hospital wants to know how many patients came in with **pneumonia** last month.
#
# ---
#
# - **Frequency** gives the **actual number of cases** — e.g., **127 admissions**.
# - This information is critical for:
#   - 🧑‍⚕️ Resource planning
#   - 👩‍💼 Staff scheduling
#   - 💰 Budgeting and supply management
# - A **percentage alone** (e.g., *5% of all visits*) hides the real workload —  the hospital needs *counts* to make operational decisions.

# %% [markdown]
# **Scenario:**
# Two hospitals report their number of pneumonia cases last month:
#
# | Hospital | Pneumonia Cases | Total Patients | Percent |
# |-----------|----------------:|----------------:|---------:|
# | City General | 127 | 2,540 | **5%** |
# | Valley Regional | 90 | 600 | **15%** |
#
# ---
#
# - **Frequencies** (127 vs. 90) make it look like City General has a bigger problem.
# - But **percentages** reveal that pneumonia was **three times more common** at Valley Regional.
# - **Percentages** let us **compare groups of different sizes** fairly.

# %% [markdown]
# # Number of Unique Categories
#
# $\color{#EF5645}{\text{Definition}}$
# The **number of unique categories** tells how many distinct values exist in the categorical variable.
#
# Counting **unique values** helps us understand **diversity**, **data quality**, and **structure** in a dataset.

# %% [markdown]
# $\color{#003660}{\text{In Python}}$, we use the function `unique()` or `nunique()` from `pandas`. Does anyone know the difference?
#
# We can also use `np.unique()` from `NumPy`.

# %%
colors.nunique()
# Out:
# 3

# %%
colors.unique()
# Out:
# array(['Red', 'Blue', 'Green'], dtype=object)

# %%
import numpy as np

np.unique(colors) #what is different here?
# Out:
# array(['Blue', 'Green', 'Red'], dtype=object)

# %%
np.unique(colors, return_counts=True) #counts with numpy!
# Out:
# (array(['Blue', 'Green', 'Red'], dtype=object), array([4, 1, 3]))

# %% [markdown]
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_data-scientist.png" alt="Mean, Median, Mode illustration" width="800px">
# </div>

# %% [markdown]
# #  📊 Visualizing Data
#
# <div style="
#   display: flex;
#   justify-content: center;
#   align-items: flex-start;
#   gap: 50px;
#   margin-top: 30px;
# ">
#
#   <!-- Left: Article preview -->
#   <div style="text-align:center; max-width:500px;">
#     <img src="figs/03_data_vis_1.webp" alt="Nature Aging article" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#     </p>
#   </div>
#
#   <!-- Right: Figure overview -->
#   <div style="text-align:center; max-width:500px;">
#     <img src="figs/03_data_vis_2.webp" alt="Study overview" style="width:100%; border:1px solid #ccc; border-radius:8px;">
#     <p style="font-size:14px; margin-top:8px; color:#444;">
#     </p>
#   </div>
# </div>

# %% [markdown]
# ## Why visualize data? A Picture Is Worth a Thousand Words
#
# <ul>
#     <li> We can scan a scatter plot with 1,000 points and spot the outlier instantly. But we can't do this with a table—we'd read linearly, one number at a time. </li>
# </ul>
#
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_benefits_of_visualizing.webp" alt="Mean, Median, Mode illustration" width="800px">
# </div>

# %% [markdown]
# # 🧠 Why Visuals Matter in Data Communication
#
# - The **Wharton School of Business** found that while only **50%** of an audience was convinced by a **verbal presentation**,
#   that number jumped to **> 66%** when **visuals** were added.
# - **90%** of the information transmitted to the brain is **visual**.
#   <small>(Source: MIT)</small>
# - The human brain can **process an image in just 13 milliseconds**.
#   <small>(Source: MIT)</small>
# - **50% of the brain surface** is active in **visual processing**.
#   <small>(Source: Piktochart)</small>
#
# ---
#
# <div style="text-align:center; margin-top:30px;">
#   <img src="figs/03_image_processing.png" alt="Time to process images vs sentences" width="600px">
#   <p style="font-size:14px

# %% [markdown]
# ## Visualizations can be misleading!
#
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_bad_plot1.jpg" alt="Mean, Median, Mode illustration" width="600px">
# </div>

# %% [markdown]
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_bad_plot2.png" alt="Mean, Median, Mode illustration" width="800px">
# </div>

# %% [markdown]
# <div style="text-align: center; margin-top: 20px;">
#   <img src="figs/03_how_to_lie_with_stats.jpg" alt="Mean, Median, Mode illustration" width=90%>
# </div>

# %% [markdown]
# # Visualizing Continous Data

# %% [markdown]
# # Continuous Data: Histogram
#
#
# $\color{#EF5645}{\text{Definition}}$ A **histogram** is a visual representation of the distribution of quantitative data. It is a diagram consisting of rectangles whose area is proportional to the frequency of a variable and whose width is equal to the class interval.
#
# $\color{#003660}{\text{In Python}}$, we use the function `hist()` from `matplotlib.pyplot`. The default is 10 bins.

# %% [markdown]
# # 📈 Histogram: What It Shows
#
# Histograms reveal the **shape** of your data — the pattern that numbers alone can’t show.
#
# ---
#
# ## 🔹 Common Distribution Shapes
#
# | Shape | Description | Example |
# |-------|--------------|----------|
# | 🟢 **Normal** *(Bell Curve)* | Most values cluster around the mean; symmetrical shape | Human heights, test scores |
# | 🟠 **Right-Skewed** *(Positive Skew)* | Long tail on the **right**; many low/moderate values, few high ones | Income, house prices |
# | 🔵 **Left-Skewed** *(Negative Skew)* | Long tail on the **left**; many high values, few low ones | Age at retirement, grades in easy classes |
#
# ---
#
# <div style="text-align:center; margin-top:30px;">
#   <img src="figs/03_skew.jpg" alt="Time to process images vs sentences" width="600px">
#   <p style="font-size:14px

# %% [markdown]
# $\color{#047C91}{\text{Exercise}}$:
# Look at the three distributions below and **order** the **mean**, **median**, and **mode** from smallest → largest.
#
# | Distribution Type | Sketch | Order |
# |-------------------|---------|--------|
# | Symmetric (Normal) | 🟢 bell curve | mean = median = mode |
# | Skewed Right (Positive Skew) | 🟠 long tail → right | ____ < ____ < ____ |
# | Skewed Left (Negative Skew) | 🔵 long tail → left | ____ > ____ > ____ |
#
#
# 💡 **Hint:**
# - The mean gets “pulled” toward the **long tail** because it’s sensitive to extreme values.

# %% [markdown]
# $\color{#047C91}{\text{Exercise}}$:
# Look at the three distributions below and **order** the **mean**, **median**, and **mode** from smallest → largest.
#
# | Distribution Type | Sketch | Order |
# |-------------------|---------|--------|
# | Symmetric (Normal) | 🟢 bell curve | mean = median = mode |
# | Skewed Right (Positive Skew) | 🟠 long tail → right | mode < median < mean |
# | Skewed Left (Negative Skew) | 🔵 long tail → left | mode > median > mean |
#
# <div style="text-align:center; margin-top:30px;">
#   <img src="figs/03_skew.webp" alt="Time to process images vs sentences" width="900px">
#   <p style="font-size:14px

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)
data = np.random.normal(100, 15, 200)
plt.hist(data, bins=100, edgecolor='yellow')
plt.title("Distribution of Test Scores")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Application
#
# I use histograms everyday to visualize and understand my data before running neural networks. Neural networks assume inputs are **reasonably well-behaved** and on similar scales.
# Histograms show if:
# - One variable is extremely skewed or has huge outliers.
# - Features are on different **scales** (e.g., age in years vs income in dollars)
#     - Need **standardization** (mean = 0, std = 1)
#     - Should be **log-transformed** to reduce skew
#
# <div style="text-align:center; margin-top:30px;">
#   <img src="figs/03_log_transform.png" alt="Time to process images vs sentences" width="500px">
#   <p style="font-size:14px

# %% [markdown]
# # 📦 Continuous Data: Box Plot
#
# $\color{#EF5645}{\text{Definition:}}$
# A **box plot** (or **box-and-whisker plot**) is a visual summary of how data are **spread** and **centered**.
# It divides the dataset into **quartiles** — showing the **median**, **25th (Q1)**, and **75th (Q3)** percentiles — and highlights **outliers** beyond the typical range.
#
# ---
#
# $\color{#00A2B8}{\text{Connection to Percentiles from last class:}}$
# - Percentiles divide ordered data into **100 equal parts**.
# - **Quartiles** divide data into **four equal parts**:
#   - **Q1 (25th percentile):** 25% of data fall below this value
#   - **Q2 (50th percentile / Median):** half of data fall below this value
#   - **Q3 (75th percentile):** 75% of data fall below this value
# - The **Interquartile Range (IQR)** = Q3 − Q1 → measures the **middle 50%** of your data.

# %% [markdown]
# ---
#
# <div style="text-align:center; margin-top:30px;">
#   <img src="figs/03_boxplot.webp" alt="Time to process images vs sentences" width="1300px">
#   <p style="font-size:14px

# %% [markdown]
# ### Steps
#
# 1. Compute $ Q_1 $ and $ Q_3 $ — the 25th and 75th percentiles.
# 2. Compute the interquartile range (IQR):
#
# $$
# \text{IQR} = Q_3 - Q_1
# $$
#
# 3. Define whisker limits:
#
# $$
# \text{Lower bound} = Q_1 - 1.5 \times \text{IQR}
# $$
#
# $$
# \text{Upper bound} = Q_3 + 1.5 \times \text{IQR}
# $$
#
# 4. The **minimum** and **maximum** shown on the whiskers are the smallest and largest data points *within* these bounds.
# 5. Any data points **beyond** those limits are plotted individually as **outliers**.

# %% [markdown]
# # 📊 Finding Q₁ and Q₃ Using the Median
#
# When data are ordered, the **median (Q₂)** splits the set in half.
# For an odd number of observations, halves can be formed in two ways.
#
# **Example:**
# $X = [1,\;2,\;3,\;4,\;5,\;6,\;7]$ → $n=7$, $Q₂=4$
#
# ---
#
# | Method | How to Split | Lower Half | Upper Half | Q₁ | Q₃ | Used By |
# |:-------|:--------------|:------------|:------------|:---:|:---:|:---------|
# | **Exclusive** | Exclude median | [1, 2, 3] | [5, 6, 7] | 2 | 6 | Textbooks, AP Stats |
# | **Inclusive** | Include median | [1, 2, 3, 4] | [4, 5, 6, 7] | 2.5 | 5.5 | NumPy, pandas, Excel, matplotlib |
#
# ---
#
# 💡 **Tip:**
# Inclusive methods are used in most software; exclusive methods appear in many traditional formulas.

# %% [markdown]
# $\color{#047C91}{\text{Exercise}}$: Interpreting a Box Plot
# Look at the box plot below and determine which dataset it represents.
#
# Question: Which data set could be represented by the box plot shown below using the exclusive method?
#
# <div style="text-align:center; margin-top:10px;">
#   <img src="figs/03_boxplot_exercise.png" alt="Box plot question" width="750px">
# </div>
#
# ### Options
#
# A. 12, 15, 17, 17, 19, 19, 22, 22, 24
# B. 13, 15, 15, 17, 19, 19, 20, 22, 24
# C. 12, 15, 15, 17, 20, 20, 20, 22, 24
# D. 12, 15, 15, 17, 19, 19, 20, 22, 24

# %% [markdown]
# ✅ **Correct Answer: D.**
# 12, 15, 15, 17, 19, 19, 20, 22, 24
#
# ---
#
# ### Explanation
#
# | Statistic | Approx. Value | How It Appears on Plot |
# |------------|----------------|------------------------|
# | Minimum | 12 | Left whisker |
# | Q1 | 15 | Left edge of box |
# | Median | 19 | Line inside box |
# | Q3 | 22 | Right edge of box |
# | Maximum | 24 | Right whisker |

# %% [markdown]
# $\color{#003660}{\text{In Python:}}$
# We can use the function `boxplot()` from `matplotlib.pyplot` or `sns.boxplot()` from `seaborn`.

# %%
np.random.seed(0)
scores = np.random.normal(loc=75, scale=10, size=100)
# Matplotlib horizontal box plot
plt.boxplot(scores, vert=False, patch_artist=True, #tells Matplotlib to draw the boxes as filled rectangles (“patches”), so you can color them using boxprops or facecolor.
            boxprops=dict(facecolor='red'))
plt.title("Distribution of Exam Scores (Matplotlib)")
plt.xlabel("Score")
plt.show()

# %% [markdown]
# # Visualizing Categorical Data

# %% [markdown]
# # Categorical Data: Bar Chart
#
#
# $\color{#EF5645}{\text{Definition:}}$
# A **bar chart** is a visual representation of the **frequency or proportion** of **categorical data**.
# Each bar represents a category, and the **height (or length)** of the bar is proportional to its count or percentage.
# Unlike histograms, **bar charts display discrete categories**, not continuous intervals.
#
# ---
#
# $\color{#003660}{\text{In Python:}}$
# We use the function `bar()` or `value_counts().plot(kind='bar')` from `matplotlib.pyplot` or `pandas`.
#
# ---
#
# <div style="text-align:center; margin-top:30px;">
#   <img src="figs/03_bar_chart.png" alt="Time to process images vs sentences" width="700px">
#   <p style="font-size:14px

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.Series(['Dog', 'Cat', 'Dog', 'Bird', 'Cat', 'Dog'])

# Plot bar chart
data.value_counts().plot(kind='bar', color='green', edgecolor='black')
plt.title("Favorite Pets in a Survey")
plt.xlabel("Animal")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Categorical Data: Pie Chart
#
# $\color{#EF5645}{\text{Definition}}$
# A **pie chart** shows how a categorical variable divides a whole into parts. Each slice represents a category’s **proportion or percentage** of the total.
#
# Pie charts are most useful when there are only a few categories and you want to emphasize **relative share**.
#
# ---
#
# $\color{#003660}{\text{In Python:}}$
# We can use the function `pie()` from `matplotlib.pyplot`.

# %%
import matplotlib.pyplot as plt

# Example data
sizes = [40, 25, 20, 15]
labels = ['Apples', 'Bananas', 'Oranges', 'Berries']

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Fruit Sales Distribution")
plt.show()

# %% [markdown]
# # The Pie Chart Controversy: When (Not) to Use It
#
# **The uncomfortable truth:** Pie charts are often misused. They aren’t “bad,” they’re **specific**.
#
# The pie chart fails when slices are too similar; angle/area judgments are poor and ranking is unclear

# %%
companies = ['Co A','Co B','Co C','Co D','Co E','Co F','Co G','Other']
shares = [15, 14, 13, 12, 11, 10, 9, 16]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), layout="constrained")

ax1.pie(shares, labels=companies, autopct='%1.1f%%', startangle=90)
ax1.set_title('Market Share (Pie): Hard to Compare')

ax2.barh(companies, shares, color='steelblue', edgecolor='black')
ax2.set_xlabel('Market Share (%)')
ax2.set_title('Market Share (Bar): Easy to Compare')
ax2.grid(axis='x', alpha=0.3)

plt.show()

# %% [markdown]
# **Good use case:** Few categories, one clearly dominant slice, message is “part of a whole.”
#
# ✅ **Use when:**
# - You have **2–5 categories**
# - One category is clearly **dominant (>50%)**
# - The goal is a **part-of-whole message**
# - You want **visual or emotional impact**, not precision

# %%
categories = ['Programs','Operations','Fundraising','Admin']
percentages = [70, 15, 10, 5]
explode = (0.1, 0, 0, 0)   # emphasize the main slice

plt.figure(figsize=(7, 5))
plt.pie(percentages, labels=categories, autopct='%1.0f%%',
        startangle=90, explode=explode, textprops={'fontsize': 12})
plt.title('Where Your Donation Goes')
plt.show()

# %% [markdown]
# # The Hospital Emergency Room Story
#
# **The Problem: Chaos in the ER**
#
# A hospital administrator faces a crisis:
# - Patient wait times are exploding
# - Complaints are up **300%**
# - The board wants answers *tomorrow*
#
# She has 10,000 patient records — arrival times, wait times, severity, outcomes.
# But where’s the problem hiding?
#
# Different visualizations will reveal different pieces of the puzzle.

# %% [markdown]
# # Chapter 1: The Histogram — “What’s Normal?”
#
# **The Question:**
# > “Are our wait times actually unusual, or do patients just feel like they’re waiting longer?”
#
# She needs to understand the **distribution** of wait times — what’s typical, what’s rare, what’s unacceptable.

# %%
wait_times = np.concatenate([
    np.random.normal(35, 15, 7000),
    np.random.normal(120, 40, 2000),
    np.random.normal(200, 30, 1000)
])

plt.figure(figsize=(10,5))
plt.hist(wait_times, bins=50, edgecolor='black', alpha=0.7, color='steelblue')
plt.axvline(60, color='green', linestyle='--', linewidth=2, label='Target: 60 min')
plt.axvline(wait_times.mean(), color='red', linestyle='--', linewidth=2,
            label=f'Actual Mean: {wait_times.mean():.0f} min')
plt.xlabel('Wait Time (minutes)')
plt.ylabel('Number of Patients')
plt.title('ER Wait Time Distribution - Q1 2024')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# What do we see?
#
# The histogram exposes *the shape* — two distinct patient experiences.
#
# The histogram reveals a **bimodal distribution** — two peaks.
#
# - **Peak 1 (~35 min):** Most patients — good performance
# - **Peak 2 (~120 min):** A shadow population waiting 2+ hours

# %% [markdown]
# # Chapter 2: The Box Plot — “Where’s the Problem?”
#
# **The Question:**
# > “Which department is failing?”
#
# The histogram proved there’s a problem.
# Now she needs **accountability** — where in the ER is the bottleneck?

# %%
np.random.seed(0)

departments = ['Triage', 'Lab', 'Radiology', 'Doctor\nConsult', 'Treatment', 'Discharge']
dept_sizes = [1500, 1500, 1500, 2500, 1500, 1500]

wait_times_by_dept = [
    np.random.normal(20, 5, dept_sizes[0]),     # Triage – short, consistent
    np.random.normal(60, 25, dept_sizes[1]),    # Lab – moderate variation
    np.random.normal(45, 15, dept_sizes[2]),    # Radiology – steady
    np.random.normal(120, 50, dept_sizes[3]),   # Doctor Consult – long, erratic
    np.random.normal(35, 10, dept_sizes[4]),    # Treatment – moderate
    np.random.normal(15, 4, dept_sizes[5])      # Discharge – quick
]

plt.figure(figsize=(12,6))
bp = plt.boxplot(wait_times_by_dept, tick_labels=departments, patch_artist=True)
colors = ['lightgreen','yellow','lightgreen','red','lightgreen','lightgreen']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

plt.axhline(60, color='green', linestyle='--', label='Target: 60 min')
plt.ylabel("Wait Time (minutes)")
plt.title("ER Wait Times by Department")
plt.legend()
plt.show()

# %% [markdown]
# **The box plot’s superpower:**
# It answers five questions at once:
# 1. What’s typical (median)?
# 2. How consistent (IQR)?
# 3. What are the extremes (whiskers)?
# 4. Any weird cases (outliers)?
# 5. Who’s performing better (comparisons)?

# %% [markdown]
# # Recap of what we saw today:
# - Summarizing Categorical Data
# - Visualizing Data
#      - Histograms, box plots, bar plots, pie charts
#
# # Next time:
# - Comparing 2 variables
#      - Correlation, Covariance, Scatter Plot
# - Input/Output
