# %% [markdown]
# # ECE-3 Lab 8

# %% [markdown]
# ## Left Inverse
# <font color='red'>**Definition**</font>
#
# A matrix $X$ that satisfies
# $$XA = I$$
# is called the *left inverse* of $A$. If such a matrix $X$ exists, we say $A$ is *left-invertible*.
#
#
# <font color='red'>**Properties**</font>
# - The left inverse of a matrix is **not** unique, except when $A$ is a 1x1 matrix i.e $A$ is a number.
# - The dimensions of the left inverse of  $A_{mxn}$ is $X_{nxm}$ i.e same as $A^T$.
#
#
# <font color='red'>**Existence**</font>
# If a matrix $A$ has a left inverse **if and only if** columns of $A$ are linearly independent.
#
#
# `Neccesary and sufficient condition`
#
#
# <font color='blue'>**Corollary**</font>
# If a matrix has more columns than rows (wide), it is not left-invertible.
#
# Example:
# $$\begin{bmatrix}
# 1 & 2 & 0 & 4 & 5\\
# 3 & 7 & 4 & 1 & 4\\
# 1 & 2 & 9 & 6 & 1\\
# \end{bmatrix}$$

# %% [markdown]
# ## Right Inverse
# <font color='red'>Definition: </font> A matrix $X$ that satisfies
# $$AX = I$$
# is called the *right inverse* of $A$. If such a matrix $X$ exists, we say $A$ is *right-invertible*.
#
# <font color='red'>**Properties**</font>
# - The right inverse of a matrix is **not** unique, except when $A$ is a 1x1 matrix i.e $A$ is a number.
# - The dimensions of the right inverse of  $A_{mxn}$ is $X_{nxm}$ i.e same as $A^T$.
#
#
# <font color='red'>**Existence**</font>
# If a matrix $A$ has a right inverse **if and only if** rows of $A$ are linearly independent.
#
#
# `Neccesary and sufficient condition`
#
#
# <font color='blue'>**Corollary**</font>
# If a matrix has more rows than columns (tall), it is not right-invertible.
#
# Example:
# $$\begin{bmatrix}
# 1 & 2\\
# 3 & 9\\
# 1 & 2\\
# 8 & 4\\
# \end{bmatrix}$$

# %% [markdown]
# ## Inverse of a matrix
# <font color='red'>Definition: </font> A matrix $X$ that satisfies
# $$AX = XA = I$$
# is called the *inverse* of $A$. If such a matrix $X$ exists, we say $A$ is *invertible*.
#
# <font color='red'>**Properties**</font>
# - The inverse of a matrix is **unique**.
# - It is simultaneously the left and right inverse of the given matrix.
# - The dimensions of the inverse of $A_{mxm}$ is $X_{mxm}$.
#
#
# <font color='red'>**Existence**</font>
# - If a matrix $A$ has an inverse **if and only if** both the left and right inverses exist i.e all the rows as well as columns of $A$ are linearly independent.
# - Clearly for $A$ to be invertible, $A$ cannot be tall or wide. Hence $A$ is a square matrix if at all it is invertible.
#
# - **NOTE:** A square matrix need not to be always invertible. This is a *neccesary* but not a *sufficient* condition.
#
# Example:
# $$\begin{bmatrix}
# 0 & 0\\
# 0 & 1\\
# \end{bmatrix}$$

# %% [markdown]
# In general the following properties are true:
#
# - $X$ is the left inverse of $A$ if and only if $X^T$ is the right inverse of $A^T$.
# - $X$ is the right inverse of $A$ if and only if $X^T$ is the left inverse of $A^T$.

# %% [markdown]
# ## Exercise - 1 (Inverse of transpose)
#
# Prove that $X$ is the left inverse of $A$ if and only if $X^T$ is the right inverse of $A^T$.

# %% [markdown]
# Solution
#
# Given $X^{T}$ is the right inverse of $A^{T}$, which implies $A^{T}X^{T}$ = $I$
#
# Taking transpose on both sides $(A^{T}X^{T})^{T}$ = $I^{T}$
#
# => $(X^{T})^{T}(A^{T})^{T}$ = $I^{T}$ (using the property that $(AB)^{T} = B^{T}A^{T}$ and transpose of identity matrix is identity matrix)
#
# => $XA = I$ (using the property that $(Q^{T})^{T}$=Q)
#
# This implies that X is the left inverse of A. Hence proved.

# %% [markdown]
# ## Exercise - 2 (Left and right inverse)
#
# Given four matrices $A,B,C,D$ which are invertible. It is also known that $C = ADB$. Find $D$ in terms of $A,B,C$.
#
# Repeat the above question when $A,C,D$ are invertible and $B$ only has a left inverse.

# %% [markdown]
# Solution
#
# Part-1
#
# $C = ADB$
#
# Multiplying with $A^{-1}$ from left of both sides => $A^{-1}C = DB$
#
# Multiplying with $B^{-1}$ from right of both sides => $A^{-1}CB^{-1} = D$
#
# Therefore, $D = A^{-1}CB^{-1}$
#
# Part-2
#
# $C = ADB$
#
# Multiplying with $A^{-1}$ from left of both sides => $A^{-1}C = DB$
#
# Multiplying with $D^{-1}$ from left of both sides => $D^{-1}A^{-1}C = B$
#
# Multiplying with $B_{Left}^{-1}$ from left of both sides => $B_{Left}^{-1}D^{-1}A^{-1}C = I$
#
# Multiplying with $C^{-1}$ from right of both sides => $B_{Left}^{-1}D^{-1}A^{-1} = C^{-1}$
#
# Multiplying with $A$ from right of both sides => $B_{Left}^{-1}D^{-1} = C^{-1}A$
#
# Multiplying with $D$ from right of both sides => $B_{Left}^{-1} = C^{-1}AD$
#
# Multiplying with $C$ from left of both sides => $CB_{Left}^{-1} = AD$
#
# Multiplying with $A^{-1}$ from left of both sides => $A^{-1}CB_{Left}^{-1} = D$
#
# Therefore, $D = A^{-1}CB_{Left}^{-1}$

# %% [markdown]
# ## Exercise - 3 (Invertibility)
#
# Let $A$ be a matrix and $x$ be a non-zero row vector ie contains 1 row. You are given the information that $xA=0$. Answer the following questions:
# - Does $A$ have a right inverse ?
# - Does $A^T$ have an inverse (ie both left and right inverse must exist) ?

# %% [markdown]
# Does  A  have a right inverse ?
#
# Since $xA = 0$ and x is a non-zero row vector, this implies that the linear combination of the rows of A is equal to zero has a non-trivial solution
#
# and therfore rows of matrix A are linearly dependent. Therefore, A does not have right inverse.
#
#
#
# Does  AT  have an inverse (ie both left and right inverse must exist) ?
#
# Since A does not right inverse, $A^{T}$ does not have left inverse.
#
# Since $A^{T}$ does not have left inverse, $A^{T}$ does not have inverse.

# %% [markdown]
# ## Exercise - 4 (Implementation of 2$\times$2 matrix inversion)

# %% [markdown]
# Recall the inverse of a $2\times2$ matrix can be calculated as follows:
# $A^{-1}=$ $\frac{1}{A_{11}A_{22}-A_{12}A_{21}}$ $\begin{bmatrix}
# A_{22} & -A_{12}\\
# -A_{21} & A_{11}\\
# \end{bmatrix}$,
# where $(A_{11}A_{22}-A_{12}A_{21})$ is called the **determinant** of a square matrix, and $\begin{bmatrix}
# A_{22} & -A_{12}\\
# -A_{21} & A_{11}\\
# \end{bmatrix}$ is called the **adjugate matrix** of $A$.

# %% [markdown]
# *   Complete the following function of $2\times2$ matrix inerse.
# *   Use `numpy.linalg.inv` to check your solution

# %%
import numpy as np
# Input : An invertible 2x2 matrix
# Output: Inverse of input matrix
def matrix_inverse(matrix):
  # TODO: calculate the adjugate matrix of the input
  
  adj = np.zeros((2,2)) # Initialize with zero matrix
  # Switch diagonal elements
  adj[0,0] = matrix[1,1]
  adj[1,1] = matrix[0,0]
  # Mutiply anti-diagonal elements with -1
  adj[1,0] = (-1)*matrix[1,0]
  adj[0,1] = (-1)*matrix[0,1]

  # TODO: calculate the determinant of the matrix
  
  det = matrix[0,0]*matrix[1,1]-matrix[1,0]*matrix[0,1]

  return adj/det

# %%
invertible_matrix = np.array([[-1, 3/2], [1, -1]])
print(matrix_inverse(invertible_matrix))
print(np.linalg.inv(invertible_matrix))
# Out:
# [[2. 3.]
#  [2. 2.]]
# [[2. 3.]
#  [2. 2.]]
